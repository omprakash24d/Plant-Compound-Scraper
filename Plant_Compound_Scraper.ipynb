# %% [markdown]
# # Documentation for Plant Compound Scraper
#
# ## Overview
# This Python script automates the extraction of natural products from the **COCONUT** database and retrieves molecular properties from **PubChem**. The program uses **Selenium** for web scraping and **requests** for API calls. Extracted data is saved to a CSV file.
#
# ---
#
# ## Dependencies
# Ensure you have the following libraries installed before running the script:
# ```bash
# pip install selenium webdriver-manager pandas tqdm requests
# ```
#
# ---
#
# ## Features
# - Scrapes **COCONUT** for natural products related to user-provided plant names.
# - Fetches molecular properties from **PubChem**, including:
#   - Molecular Formula
#   - Molecular Weight
#   - IUPAC Name
#   - Canonical SMILES
#   - Compound CID
# - Uses **ThreadPoolExecutor** for efficient parallel processing.
# - Saves extracted data into a CSV file for easy access.
#
# ---
#
# ## Best Practices to Ensure Optimal Results
# 1. **Ensure Correct Spelling of Plant Names**: Incorrect spellings can lead to no results or incorrect data.
# 2. **Run in a Stable Network Environment**: The script relies on API calls and web scraping, which need stable internet connectivity.
# 3. **Use a Headless Browser for Performance**: The script is optimized for Google Colab with `--headless` mode enabled.
# 4. **Avoid Overloading Servers**: Excessive requests may lead to temporary bans. Keep `time.sleep(2)` to prevent this.
# 5. **Verify Data Integrity**: Check the CSV output for missing or incorrect values before proceeding with analysis.
# 6. **Keep ChromeDriver Updated**: Use `webdriver-manager` to always fetch the latest ChromeDriver version.
# 7. **Monitor Errors and Logs**: The script prints error messages for debugging in case of failures.
#
# ---
#
# ## Script Breakdown
# ### 1. `setup_driver()`
# Initializes the **Selenium WebDriver** for scraping data from **COCONUT**.
#
# ### 2. `scrape_coconut_database(plant_name: str) -> List[str]`
# Searches for compounds related to the input plant in the **COCONUT** database and extracts their names.
#
# ### 3. `fetch_pubchem_properties(compound_name: str) -> Tuple[str, str, str, str]`
# Queries **PubChem** for molecular properties using the **PUG REST API**.
#
# ### 4. `fetch_pubchem_cid(compound_name: str) -> str`
# Retrieves the **Compound ID (CID)** for a given compound from **PubChem**.
#
# ### 5. `save_results_to_csv(data: Dict[str, List[str]], filename: str)`
# Saves the extracted data into a **CSV file**.
#
# ### 6. `process_compound(plant: str, compound: str, extracted_data: Dict[str, List[str]])`
# Processes each compound in parallel using **ThreadPoolExecutor**.
#
# ### 7. `main()`
# Handles user input, initiates scraping, and saves data.
#
# ---
#
# ## Running the Script
# Run the script in a Python environment:
# ```bash
# python script.py
# ```
# Follow the prompt and enter plant names as comma-separated values.
#
# ---
#
# ## Output
# A **CSV file (`natural_products.csv`)** containing extracted data with the following columns:
# - **Plant**: Name of the input plant.
# - **Compound**: Extracted compound name.
# - **CID**: PubChem Compound ID.
# - **MolecularFormula**: Chemical formula.
# - **MolecularWeight**: Molecular weight.
# - **IUPACName**: Standard chemical name.
# - **CanonicalSMILES**: Machine-readable molecular structure.
#
# ---
#
# ## Error Handling
# - If a compound is **not found** on PubChem, `N/A` is recorded.
# - **Exceptions** during scraping or API calls are logged with appropriate messages.
# - The script **skips** plants with no identified compounds.
#
# ---
#
# ## Conclusion
# This script is an efficient way to gather phytochemical data for research. Follow the best practices to maximize accuracy and performance.

# %% [markdown]
# #Instruction
# NCBI’s PubChem API has the following usage limits (as per their guidelines):
# Unauthenticated Requests:
# Maximum 5 requests per second.
#
# Maximum 10,000 requests per day.
#
# Authenticated Requests (with API key):
# Maximum 10 requests per second.
#
# Maximum 100,000 requests per day.
#
# Concurrent Connections: Limited to 5 simultaneous connections per IP.
#
# Make sure you don't cross the limitation otherwise your ip will get blocked and you will not get any result

# %% [markdown]
# #Plants/ Herbs Names from the assignments

# %% [markdown]
# Aloe vera, Phyllanthus emblica, Murraya koenigii, Cinnamomum camphora, Cocos nucifera, Eclipta prostrata, Hibiscus rosa-sinensis, Lawsonia inermis, Azadirachta indica, Trigonella foenum-graecum, Salvia officinalis, Achyranthes aspera, Allium cepa, Vitis vinifera, Nardostachys jatamansi, Rosmarinus officinalis, Thymus vulgaris, Ocimum tenuiflorum, Allium sativum, Serenoa repens, Panax ginseng, Urtica dioica, Ricinus communis, Simmondsia chinensis, Arnica montana, Capsicum annuum, Nigella sativa, Acacia concinna, Moringa oleifera, Terminalia bellirica, Withania somnifera, Polygonum multiflorum, Angelica sinensis, Lycium barbarum, Ganoderma lucidum, Schisandra chinensis, Carthamus tinctorius, Cinnamomum verum, Angelica archangelica, Bacopa monnieri, Brassica juncea, Arctium lappa, Catharanthus roseus, Capsicum frutescens, Curcuma longa, Cymbopogon citratus, Cyperus rotundus, Equisetum arvense, Linum usitatissimum, Zingiber officinale, Glycyrrhiza glabra, Lavandula angustifolia, Citrus limon, Melaleuca alternifolia, Mentha piperita, Piper nigrum, Cucurbita pepo, Oryza sativa, Santalum album, Sapindus mukorossi, Scutellaria baicalensis, Sesamum indicum, Syzygium aromaticum, Thuja occidentalis

# %% [markdown]
# #More Plants

# %% [markdown]
# Aloe vera, Phyllanthus emblica, Murraya koenigii, Cinnamomum camphora, Cocos nucifera, Eclipta prostrata, Hibiscus rosa-sinensis, Lawsonia inermis, Azadirachta indica, Trigonella foenum-graecum, Salvia officinalis, Achyranthes aspera, Allium cepa, Vitis vinifera, Nardostachys jatamansi, Rosmarinus officinalis, Thymus vulgaris, Ocimum tenuiflorum, Allium sativum, Serenoa repens, Panax ginseng, Urtica dioica, Ricinus communis, Simmondsia chinensis, Arnica montana, Capsicum annuum, Nigella sativa, Acacia concinna, Moringa oleifera, Terminalia bellirica, Withania somnifera, Polygonum multiflorum, Angelica sinensis, Lycium barbarum, Ganoderma lucidum, Schisandra chinensis, Carthamus tinctorius, Cinnamomum verum, Angelica archangelica, Bacopa monnieri, Brassica juncea, Arctium lappa, Catharanthus roseus, Capsicum frutescens, Curcuma longa, Cymbopogon citratus, Cyperus rotundus, Equisetum arvense, Linum usitatissimum, Zingiber officinale, Glycyrrhiza glabra, Lavandula angustifolia, Citrus limon, Melaleuca alternifolia, Mentha piperita, Piper nigrum, Cucurbita pepo, Oryza sativa, Santalum album, Sapindus mukorossi, Scutellaria baicalensis, Sesamum indicum, Syzygium aromaticum, Thuja occidentalis, Achyranthes aspera, Bacopa monnieri, Ginkgo biloba, Camellia sinensis, Fucus vesiculosus, Polygonum cuspidatum, Foeniculum vulgare, Astragalus membranaceus, Apium graveolens, Celosia argentea, Angelica dahurica, Rheum palmatum, Paeonia lactiflora, Perilla frutescens, Prunus persica, Prunus mume.

# %% [markdown]
# #Some More plants from Patanjali Keshkanti Oil Composition

# %% [markdown]
# ##Common Name

# %% [markdown]
# Aloe Vera,Indian Gooseberry (Amla),Curry Leaves,Camphor,Coconut Oil,Bhringraj,Hibiscus,Henna,Neem,Fenugreek,Sage,Prickly Chaff Flower,Onion,Grape Seed Extract,Spikenard,Rosemary,Thyme,Holy Basil (Tulsi),Garlic,Saw Palmetto,Ginseng,Stinging Nettle,Castor Oil,Jojoba Oil,Arnica,Cayenne Pepper,Black Seed,Shikakai,Moringa,Baheda,Ashwagandha,Fo-Ti,Dong Quai,Goji Berry,Reishi Mushroom,Schisandra,Safflower,True Cinnamon,Angelica Root,Brahmi,Mustard,Burdock Root,Madagascar Periwinkle,Chili Pepper,Turmeric,Lemongrass,Nutgrass,Horsetail,Flaxseed,Ginger,Licorice Root,Lavender,Lemon,Tea Tree Oil,Peppermint,Black Pepper,Pumpkin Seed,Rice Extract,Sandalwood,Soapnut,Baikal Skullcap,Sesame,Clove,White Cedar,Ginkgo,Green Tea,Bladderwrack,Japanese Knotweed,Fennel,Astragalus,Celery,Cockscomb,Dahurian Angelica,Rhubarb,Chinese Peony,Perilla,Peach,Japanese Apricot,Bhringraj,Curry,Kalonji,Nimbu (Lemon),Coconut,Gurhal (Hibiscus),Ghrit Kumari (Aloe Vera),Vijaya (Cannabis),Manjistha,Amla (Indian Gooseberry),Malkangani,Vat Jata (Banyan Tree),Methi (Fenugreek),Henna,Shikakai,Brahmi,Castor,Rose hip,Neem,Mandookparni (Gotu Kola),Ratanjot,Charila (Stone Flower),Reetha (Soapnut),Jatamansi (Spikenard),Laal Chandan (Red Sandalwood),Devdaru (Himalayan Cedar),Cajuput

# %% [markdown]
# ##Scientific Name

# %% [markdown]
# Aloe vera,Phyllanthus emblica,Murraya koenigii,Cinnamomum camphora,Cocos nucifera,Eclipta prostrata,Hibiscus rosa-sinensis,Lawsonia inermis,Azadirachta indica,Trigonella foenum-graecum,Salvia officinalis,Achyranthes aspera,Allium cepa,Vitis vinifera,Nardostachys jatamansi,Rosmarinus officinalis,Thymus vulgaris,Ocimum tenuiflorum,Allium sativum,Serenoa repens,Panax ginseng,Urtica dioica,Ricinus communis,Simmondsia chinensis,Arnica montana,Capsicum annuum,Nigella sativa,Acacia concinna,Moringa oleifera,Terminalia bellirica,Withania somnifera,Polygonum multiflorum,Angelica sinensis,Lycium barbarum,Ganoderma lucidum,Schisandra chinensis,Carthamus tinctorius,Cinnamomum verum,Angelica archangelica,Bacopa monnieri,Brassica juncea,Arctium lappa,Catharanthus roseus,Capsicum frutescens,Curcuma longa,Cymbopogon citratus,Cyperus rotundus,Equisetum arvense,Linum usitatissimum,Zingiber officinale,Glycyrrhiza glabra,Lavandula angustifolia,Citrus limon,Melaleuca alternifolia,Mentha piperita,Piper nigrum,Cucurbita pepo,Oryza sativa,Santalum album,Sapindus mukorossi,Scutellaria baicalensis,Sesamum indicum,Syzygium aromaticum,Thuja occidentalis,Ginkgo biloba,Camellia sinensis,Fucus vesiculosus,Polygonum cuspidatum,Foeniculum vulgare,Astragalus membranaceus,Apium graveolens,Celosia argentea,Angelica dahurica,Rheum palmatum,Paeonia lactiflora,Perilla frutescens,Prunus persica,Prunus mume,Eclipta alba,Murraya koenigii,Nigella sativa,Citrus limon,Cocos nucifera,Hibiscus rosa-sinensis,Aloe barbadensis,Cannabis sativa,Rubia cordifolia,Emblica officinalis,Celastrus paniculatus,Ficus benghalensis,Trigonella foenum-graecum,Lawsonia inermis,Acacia concinna,Bacopa monnieri,Ricinus communis,Rosa moschata,Azadirachta indica,Centella asiatica,Geranium wallichianum,Parmelia perlata,Sapindus trifoliatus,Nardostachys jatamansi,Pterocarpus santalinus,Cedrus deodara,Melaleuca leucadendron

# %%
#Required Libraries
# !apt-get update
# !apt-get install -y chromium-chromedriver
# !pip install selenium webdriver-manager
# Out:
# Collecting selenium
#   Downloading selenium-4.29.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.3.0)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from webdriver-manager) (2.32.3)
# Collecting python-dotenv (from webdriver-manager)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (25.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (3.10)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->webdriver-manager) (3.4.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.29.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 27.3 MB/s eta 0:00:00
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 15.4 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, python-dotenv, outcome, webdriver-manager, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 python-dotenv-1.0.1 selenium-4.29.0 trio-0.29.0 trio-websocket-0.12.2 webdriver-manager-4.0.2 wsproto-1.2.0

# %%
import os
import time
import pandas as pd
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from typing import List, Dict, Tuple
from google.colab import files  # Google Colab file upload

# 🚀 Setup Selenium WebDriver for headless browsing
def setup_driver():
    """🌐 Setup Selenium WebDriver for scraping."""
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--window-size=1920,1080")

    service = Service()
    return webdriver.Chrome(service=service, options=chrome_options)

# 🔎 Scrape compound names from the COCONUT database
def scrape_coconut_database(plant_name: str) -> List[str]:
    """Scrapes compound names from the COCONUT database."""
    search_url = f"https://coconut.naturalproducts.net/search?q={plant_name.replace(' ', '+')}"
    print(f"\n🔍 Searching compounds for {plant_name} in the 🥥 COCONUT Database...")

    driver = setup_driver()
    driver.get(search_url)
    time.sleep(2)  # Allow page to load

    try:
        compounds = [elem.text.strip() for elem in driver.find_elements(By.XPATH, "//h3[contains(@class, 'text-gray-900')]") if elem.text.strip()]
    except Exception as e:
        print(f"❌ Error extracting compounds for {plant_name}: {e}")
        compounds = []

    driver.quit()
    print(f"✅ Found {len(compounds)} compounds: {compounds}" if compounds else f"⚠️ No compounds found for {plant_name}.")
    return compounds

# ⚛️ Fetch molecular properties from PubChem
def fetch_pubchem_properties(compound_name: str) -> Tuple[str, str, str, str]:
    """Retrieves molecular properties from PubChem."""
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{compound_name}/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        props = data.get("PropertyTable", {}).get("Properties", [{}])[0]
        return (
            props.get("MolecularFormula", "N/A"),
            str(props.get("MolecularWeight", "N/A")),
            props.get("IUPACName", "N/A"),
            props.get("CanonicalSMILES", "N/A"),
        )
    except (requests.RequestException, KeyError) as e:
        print(f"⚠️ Error retrieving PubChem data for {compound_name}: {e}")
        return "N/A", "N/A", "N/A", "N/A"

# 🆔 Fetch the CID (Compound ID) from PubChem
def fetch_pubchem_cid(compound_name: str) -> str:
    """Fetches the CID (Compound ID) from PubChem."""
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{compound_name}/cids/JSON"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        return str(data.get("IdentifierList", {}).get("CID", ["N/A"])[0])
    except (requests.RequestException, KeyError) as e:
        print(f"⚠️ Error fetching CID for {compound_name}: {e}")
        return "N/A"

# 💾 Save extracted data to a CSV file
def save_results_to_csv(data: Dict[str, List[str]], filename: str = "natural_products.csv") -> None:
    """Saves extracted compound data to a CSV file."""
    df = pd.DataFrame(data)
    try:
        df.to_csv(filename, index=False, encoding="utf-8")
        print(f"\n✅ Data successfully saved to `{filename}`!")
    except Exception as e:
        print(f"\n❌ Error saving file: {e}")

# 📂 File Upload & Manual Input Handling (ONLY CSV ACCEPTED)
def get_plant_names():
    """Allows users to upload a CSV file or manually enter plant names."""
    print("\n📢 INSTRUCTIONS:")
    print("✔️ Please upload a CSV file containing valid compound names.")
    print("✔️ The file should have no headers and only contain compound names separated by commas.")
    print("✔️ If you don’t have a file, you can enter plant names manually.")
    print("❌ Only CSV files are accepted!")

    choice = input("\n📌 Do you want to upload a CSV file? (yes/no): ").strip().lower()

    if choice == "yes":
        print("📤 Please upload your CSV file...")
        uploaded = files.upload()  # Opens file upload dialog

        if uploaded:
            filename = list(uploaded.keys())[0]  # Get the uploaded file name

            # 🚨 Reject non-CSV files
            if not filename.endswith(".csv"):
                print(f"\n❌ Error: `{filename}` is not a CSV file. Please upload a valid `.csv` file!")
                return get_plant_names()  # Prompt user again

            # ✅ Read CSV (without header)
            try:
                df = pd.read_csv(filename, header=None)
                plants = df.iloc[:, 0].tolist()  # Extract first column
                plants = [p.strip().lower() for p in plants if p.strip()]
                print(f"✅ Successfully loaded `{len(plants)}` plant names from `{filename}`.")
                return plants
            except Exception as e:
                print(f"\n❌ Error reading `{filename}`: {e}. Please upload a valid CSV file.")
                return get_plant_names()  # Prompt user again
        else:
            print("⚠️ No file uploaded. Switching to manual input...")

    # 📌 Manual Input Fallback
    plants = input("🌿 Enter plant/herb names (comma-separated): ").split(",")
    return [p.strip().lower() for p in plants if p.strip()]

# 🔄 Process each compound sequentially
def process_compound(plant: str, compound: str, extracted_data: Dict[str, List[str]]):
    """Processes each compound and retrieves molecular data."""
    formula, weight, iupac, smiles = fetch_pubchem_properties(compound)
    extracted_data["Plant"].append(plant)
    extracted_data["Compound"].append(compound)
    extracted_data["CID"].append(fetch_pubchem_cid(compound))
    extracted_data["MolecularFormula"].append(formula)
    extracted_data["MolecularWeight"].append(weight)
    extracted_data["IUPACName"].append(iupac)
    extracted_data["CanonicalSMILES"].append(smiles)

# 🚀 Main Function
def main() -> None:
    """Main function to orchestrate data collection."""
    plant_names = get_plant_names()

    if not plant_names:
        print("⚠️ No plant names provided. Exiting...")
        return

    print(f"\n🌱 Searching for {len(plant_names)} plants...")

    # 📊 Initialize data storage
    extracted_data: Dict[str, List[str]] = {
        "Plant": [], "Compound": [], "CID": [], "MolecularFormula": [], "MolecularWeight": [], "IUPACName": [], "CanonicalSMILES": []
    }

    for plant in plant_names:
        compounds = scrape_coconut_database(plant)
        if not compounds:
            continue  # Skip if no compounds found

        for compound in compounds:
            print(f"🔄 Processing {compound} from {plant}...")
            process_compound(plant, compound, extracted_data)

    if extracted_data["Plant"]:
        save_results_to_csv(extracted_data)
    else:
        print("\n⚠️ No data extracted!")

if __name__ == "__main__":
    main()
# Out:
# 📢 INSTRUCTIONS:
# ✔️ Please upload a CSV file containing valid compound names.
# ✔️ The file should have no headers and only contain compound names separated by commas.
# ✔️ If you don’t have a file, you can enter plant names manually.
# ❌ Only CSV files are accepted!
#
# 📌 Do you want to upload a CSV file? (yes/no):
# 🌿 Enter plant/herb names (comma-separated): Aloe vera, Phyllanthus emblica, Murraya koenigii, Cinnamomum camphora, Cocos nucifera, Eclipta prostrata, Hibiscus rosa-sinensis, Lawsonia inermis, Azadirachta indica, Trigonella foenum-graecum, Salvia officinalis, Achyranthes aspera, Allium cepa, Vitis vinifera, Nardostachys jatamansi, Rosmarinus officinalis, Thymus vulgaris, Ocimum tenuiflorum, Allium sativum, Serenoa repens, Panax ginseng, Urtica dioica, Ricinus communis, Simmondsia chinensis, Arnica montana, Capsicum annuum, Nigella sativa, Acacia concinna, Moringa oleifera, Terminalia bellirica, Withania somnifera, Polygonum multiflorum, Angelica sinensis, Lycium barbarum, Ganoderma lucidum, Schisandra chinensis, Carthamus tinctorius, Cinnamomum verum, Angelica archangelica, Bacopa monnieri, Brassica juncea, Arctium lappa, Catharanthus roseus, Capsicum frutescens, Curcuma longa, Cymbopogon citratus, Cyperus rotundus, Equisetum arvense, Linum usitatissimum, Zingiber officinale, Glycyrrhiza glabra, Lavandula angustifolia, Citrus limon, Melaleuca alternifolia, Mentha piperita, Piper nigrum, Cucurbita pepo, Oryza sativa, Santalum album, Sapindus mukorossi, Scutellaria baicalensis, Sesamum indicum, Syzygium aromaticum, Thuja occidentalis, Achyranthes aspera, Bacopa monnieri, Ginkgo biloba, Camellia sinensis, Fucus vesiculosus, Polygonum cuspidatum, Foeniculum vulgare, Astragalus membranaceus, Apium graveolens, Celosia argentea, Angelica dahurica, Rheum palmatum, Paeonia lactiflora, Perilla frutescens, Prunus persica, Prunus mume
#
# 🌱 Searching for 80 plants...
#
# 🔍 Searching compounds for aloe vera in the 🥥 COCONUT Database...
# ✅ Found 4 compounds: ['Isopropyl Alcohol', 'Benzethonium Chloride', 'Triclosan', '4-Chloro-3,5-Dimethylphenol']
# 🔄 Processing Isopropyl Alcohol from aloe vera...
# 🔄 Processing Benzethonium Chloride from aloe vera...
# 🔄 Processing Triclosan from aloe vera...
# 🔄 Processing 4-Chloro-3,5-Dimethylphenol from aloe vera...
#
# 🔍 Searching compounds for phyllanthus emblica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from phyllanthus emblica...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for murraya koenigii in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from murraya koenigii...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for cinnamomum camphora in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from cinnamomum camphora...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for cocos nucifera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from cocos nucifera...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for eclipta prostrata in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from eclipta prostrata...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for hibiscus rosa-sinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from hibiscus rosa-sinensis...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for lawsonia inermis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from lawsonia inermis...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for azadirachta indica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Nimbolide']
# 🔄 Processing Nimbolide from azadirachta indica...
#
# 🔍 Searching compounds for trigonella foenum-graecum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from trigonella foenum-graecum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for salvia officinalis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Epiisorosmanol']
# 🔄 Processing Epiisorosmanol from salvia officinalis...
#
# 🔍 Searching compounds for achyranthes aspera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from achyranthes aspera...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for allium cepa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from allium cepa...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for vitis vinifera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['ETHYL HEPTANOATE']
# 🔄 Processing ETHYL HEPTANOATE from vitis vinifera...
#
# 🔍 Searching compounds for nardostachys jatamansi in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from nardostachys jatamansi...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for rosmarinus officinalis in the 🥥 COCONUT Database...
# ✅ Found 3 compounds: ['(4aR)-5,6-Dihydroxy-1,1-Dimethyl-7-Propan-2-Yl-2,3,4,9,10,10a-Hexahydrophenanthrene-4a-Carboxylic Acid', '7-O-Methylrosmanol', 'Carnosic Acid']
# 🔄 Processing (4aR)-5,6-Dihydroxy-1,1-Dimethyl-7-Propan-2-Yl-2,3,4,9,10,10a-Hexahydrophenanthrene-4a-Carboxylic Acid from rosmarinus officinalis...
# 🔄 Processing 7-O-Methylrosmanol from rosmarinus officinalis...
# 🔄 Processing Carnosic Acid from rosmarinus officinalis...
#
# 🔍 Searching compounds for thymus vulgaris in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from thymus vulgaris...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for ocimum tenuiflorum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from ocimum tenuiflorum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for allium sativum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from allium sativum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for serenoa repens in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from serenoa repens...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for panax ginseng in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Panax Ginseng Tetrapeptide']
# 🔄 Processing Panax Ginseng Tetrapeptide from panax ginseng...
#
# 🔍 Searching compounds for urtica dioica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from urtica dioica...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for ricinus communis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from ricinus communis...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for simmondsia chinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from simmondsia chinensis...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for arnica montana in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from arnica montana...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for capsicum annuum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Acetal']
# 🔄 Processing Acetal from capsicum annuum...
#
# 🔍 Searching compounds for nigella sativa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from nigella sativa...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for acacia concinna in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from acacia concinna...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for moringa oleifera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from moringa oleifera...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for terminalia bellirica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from terminalia bellirica...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for withania somnifera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Withanolide D']
# 🔄 Processing Withanolide D from withania somnifera...
#
# 🔍 Searching compounds for polygonum multiflorum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from polygonum multiflorum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for angelica sinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from angelica sinensis...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for lycium barbarum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from lycium barbarum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for ganoderma lucidum in the 🥥 COCONUT Database...
# ✅ Found 3 compounds: ['Ganoderic Acid B', 'Ganoderic Acid A', 'ERGOSTEROL']
# 🔄 Processing Ganoderic Acid B from ganoderma lucidum...
# 🔄 Processing Ganoderic Acid A from ganoderma lucidum...
# 🔄 Processing ERGOSTEROL from ganoderma lucidum...
#
# 🔍 Searching compounds for schisandra chinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Schisandrin']
# 🔄 Processing Schisandrin from schisandra chinensis...
#
# 🔍 Searching compounds for carthamus tinctorius in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from carthamus tinctorius...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for cinnamomum verum in the 🥥 COCONUT Database...
# ✅ Found 4 compounds: ['Eugenol', 'Cinnamtannin B2', 'Cinnamtannin B1', 'Coumarin']
# 🔄 Processing Eugenol from cinnamomum verum...
# 🔄 Processing Cinnamtannin B2 from cinnamomum verum...
# 🔄 Processing Cinnamtannin B1 from cinnamomum verum...
# 🔄 Processing Coumarin from cinnamomum verum...
#
# 🔍 Searching compounds for angelica archangelica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Isopimpinellin']
# 🔄 Processing Isopimpinellin from angelica archangelica...
#
# 🔍 Searching compounds for bacopa monnieri in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from bacopa monnieri...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for brassica juncea in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from brassica juncea...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for arctium lappa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from arctium lappa...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for catharanthus roseus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from catharanthus roseus...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for capsicum frutescens in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from capsicum frutescens...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for curcuma longa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from curcuma longa...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for cymbopogon citratus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from cymbopogon citratus...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for cyperus rotundus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from cyperus rotundus...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for equisetum arvense in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from equisetum arvense...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for linum usitatissimum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from linum usitatissimum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for zingiber officinale in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from zingiber officinale...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for glycyrrhiza glabra in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from glycyrrhiza glabra...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for lavandula angustifolia in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from lavandula angustifolia...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for citrus limon in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from citrus limon...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for melaleuca alternifolia in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from melaleuca alternifolia...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for mentha piperita in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from mentha piperita...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for piper nigrum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from piper nigrum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for cucurbita pepo in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from cucurbita pepo...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for oryza sativa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from oryza sativa...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for santalum album in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['5-[(1S,3R)-2,3-Dimethyl-3-Tricyclo[2.2.1.02,6]Heptanyl]-2-Methylpent-2-En-1-Ol;2-Methyl-5-[(1S,2R,4R)-2-Methyl-3-Methylidene-2-Bicyclo[2.2.1]Heptanyl]Pent-2-En-1-Ol']
# 🔄 Processing 5-[(1S,3R)-2,3-Dimethyl-3-Tricyclo[2.2.1.02,6]Heptanyl]-2-Methylpent-2-En-1-Ol;2-Methyl-5-[(1S,2R,4R)-2-Methyl-3-Methylidene-2-Bicyclo[2.2.1]Heptanyl]Pent-2-En-1-Ol from santalum album...
#
# 🔍 Searching compounds for sapindus mukorossi in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from sapindus mukorossi...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for scutellaria baicalensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from scutellaria baicalensis...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for sesamum indicum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from sesamum indicum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for syzygium aromaticum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from syzygium aromaticum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for thuja occidentalis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from thuja occidentalis...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for achyranthes aspera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from achyranthes aspera...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for bacopa monnieri in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from bacopa monnieri...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for ginkgo biloba in the 🥥 COCONUT Database...
# ✅ Found 4 compounds: ['Ginkgolide A', 'Bilobalide', 'Ginkgolide B', 'Ginkgolide A']
# 🔄 Processing Ginkgolide A from ginkgo biloba...
# 🔄 Processing Bilobalide from ginkgo biloba...
# 🔄 Processing Ginkgolide B from ginkgo biloba...
# 🔄 Processing Ginkgolide A from ginkgo biloba...
#
# 🔍 Searching compounds for camellia sinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from camellia sinensis...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for fucus vesiculosus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['(2S,3S,4S,5S,6R)-4,5-Dihydroxy-2,6-Dimethyltetrahydro-2H-Pyran-3-Yl Hydrogen Sulfate']
# 🔄 Processing (2S,3S,4S,5S,6R)-4,5-Dihydroxy-2,6-Dimethyltetrahydro-2H-Pyran-3-Yl Hydrogen Sulfate from fucus vesiculosus...
#
# 🔍 Searching compounds for polygonum cuspidatum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from polygonum cuspidatum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for foeniculum vulgare in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from foeniculum vulgare...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for astragalus membranaceus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from astragalus membranaceus...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for apium graveolens in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from apium graveolens...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for celosia argentea in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from celosia argentea...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for angelica dahurica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from angelica dahurica...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for rheum palmatum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from rheum palmatum...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for paeonia lactiflora in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from paeonia lactiflora...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for perilla frutescens in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from perilla frutescens...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for prunus persica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from prunus persica...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# 🔍 Searching compounds for prunus mume in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# 🔄 Processing No results from prunus mume...
# ⚠️ Error retrieving PubChem data for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON
# ⚠️ Error fetching CID for No results: 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/No%20results/cids/JSON
#
# ✅ Data successfully saved to `natural_products.csv`!

# %%
import os
import time
import pandas as pd
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from typing import List, Dict, Tuple
from google.colab import files  # Google Colab file upload

# 🚀 Setup Selenium WebDriver for headless browsing
def setup_driver():
    """🌐 Setup Selenium WebDriver for scraping."""
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--window-size=1920,1080")

    service = Service()
    return webdriver.Chrome(service=service, options=chrome_options)

# 🔎 Scrape compound names from the COCONUT database
def scrape_coconut_database(plant_name: str) -> List[str]:
    """Scrapes compound names from the COCONUT database."""
    search_url = f"https://coconut.naturalproducts.net/search?q={plant_name.replace(' ', '+')}"
    print(f"\n🔍 Searching compounds for {plant_name} in the 🥥 COCONUT Database...")

    driver = setup_driver()
    driver.get(search_url)
    time.sleep(2)  # Allow page to load

    try:
        compounds = [elem.text.strip() for elem in driver.find_elements(By.XPATH, "//h3[contains(@class, 'text-gray-900')]") if elem.text.strip()]
    except Exception as e:
        print(f"❌ Error extracting compounds for {plant_name}: {e}")
        compounds = []

    driver.quit()
    print(f"✅ Found {len(compounds)} compounds: {compounds}" if compounds else f"⚠️ No compounds found for {plant_name}.")
    return compounds

# ⚛️ Fetch molecular properties from PubChem
def fetch_pubchem_properties(compound_name: str) -> Tuple[str, str, str, str]:
    """Retrieves molecular properties from PubChem."""
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{compound_name}/property/MolecularFormula,MolecularWeight,IUPACName,CanonicalSMILES/JSON"
    time.sleep(1.5)
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        props = data.get("PropertyTable", {}).get("Properties", [{}])[0]
        return (
            props.get("MolecularFormula", "N/A"),
            str(props.get("MolecularWeight", "N/A")),
            props.get("IUPACName", "N/A"),
            props.get("CanonicalSMILES", "N/A"),
        )
    except (requests.RequestException, KeyError) as e:
        print(f"⚠️ Error retrieving PubChem data for {compound_name}: {e}")
        return "N/A", "N/A", "N/A", "N/A"

# 🆔 Fetch the CID (Compound ID) from PubChem
def fetch_pubchem_cid(compound_name: str) -> str:
    """Fetches the CID (Compound ID) from PubChem."""
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{compound_name}/cids/JSON"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        return str(data.get("IdentifierList", {}).get("CID", ["N/A"])[0])
    except (requests.RequestException, KeyError) as e:
        print(f"⚠️ Error fetching CID for {compound_name}: {e}")
        return "N/A"

# 💾 Save extracted data to a CSV file
def save_results_to_csv(data: Dict[str, List[str]], filename: str = "natural_products.csv") -> None:
    """Saves extracted compound data to a CSV file."""
    df = pd.DataFrame(data)
    try:
        df.to_csv(filename, index=False, encoding="utf-8")
        print(f"\n✅ Data successfully saved to `{filename}`!")
    except Exception as e:
        print(f"\n❌ Error saving file: {e}")

# 📂 File Upload & Manual Input Handling (ONLY CSV ACCEPTED)
def get_plant_names():
    """Allows users to upload a CSV file or manually enter plant names."""
    print("\n📢 INSTRUCTIONS:")
    print("✔️ Please upload a CSV file containing valid compound names.")
    print("✔️ The file should have no headers and only contain compound names separated by commas.")
    print("✔️ If you don’t have a file, you can enter plant names manually.")
    print("❌ Only CSV files are accepted!")

    choice = input("\n📌 Do you want to upload a CSV file? (yes/no): ").strip().lower()

    if choice == "yes":
        print("📤 Please upload your CSV file...")
        uploaded = files.upload()  # Opens file upload dialog

        if uploaded:
            filename = list(uploaded.keys())[0]  # Get the uploaded file name

            # 🚨 Reject non-CSV files
            if not filename.endswith(".csv"):
                print(f"\n❌ Error: `{filename}` is not a CSV file. Please upload a valid `.csv` file!")
                return get_plant_names()  # Prompt user again

            # ✅ Read CSV (without header)
            try:
                df = pd.read_csv(filename, header=None)
                plants = df.iloc[:, 0].tolist()  # Extract first column
                plants = [p.strip().lower() for p in plants if p.strip()]
                print(f"✅ Successfully loaded `{len(plants)}` plant names from `{filename}`.")
                return plants
            except Exception as e:
                print(f"\n❌ Error reading `{filename}`: {e}. Please upload a valid CSV file.")
                return get_plant_names()  # Prompt user again
        else:
            print("⚠️ No file uploaded. Switching to manual input...")

    # 📌 Manual Input Fallback
    plants = input("🌿 Enter plant/herb names (comma-separated): ").split(",")
    return [p.strip().lower() for p in plants if p.strip()]

# 🔄 Process each compound sequentially
def process_compound(plant: str, compound: str, extracted_data: Dict[str, List[str]]):
    """Processes each compound and retrieves molecular data."""
    formula, weight, iupac, smiles = fetch_pubchem_properties(compound)
    extracted_data["Plant"].append(plant)
    extracted_data["Compound"].append(compound)
    extracted_data["CID"].append(fetch_pubchem_cid(compound))
    extracted_data["MolecularFormula"].append(formula)
    extracted_data["MolecularWeight"].append(weight)
    extracted_data["IUPACName"].append(iupac)
    extracted_data["CanonicalSMILES"].append(smiles)

# 🚀 Main Function
def main() -> None:
    """Main function to orchestrate data collection."""
    plant_names = get_plant_names()

    if not plant_names:
        print("⚠️ No plant names provided. Exiting...")
        return

    print(f"\n🌱 Searching for {len(plant_names)} plants...")

    # 📊 Initialize data storage
    extracted_data: Dict[str, List[str]] = {
        "Plant": [], "Compound": [], "CID": [], "MolecularFormula": [], "MolecularWeight": [], "IUPACName": [], "CanonicalSMILES": []
    }

    for plant in plant_names:
        compounds = scrape_coconut_database(plant)

        # 🚨 Skip processing if the only result is "No results"
        if not compounds or compounds == ["No results"]:
            print(f"⚠️ Skipping PubChem search for {plant} as no valid compounds were found.")
            continue  # Skip this plant

        for compound in compounds:
            print(f"🔄 Processing {compound} from {plant}...")
            process_compound(plant, compound, extracted_data)

    if extracted_data["Plant"]:
        save_results_to_csv(extracted_data)
    else:
        print("\n⚠️ No data extracted!")

if __name__ == "__main__":
    main()
# Out:
# 📢 INSTRUCTIONS:
# ✔️ Please upload a CSV file containing valid compound names.
# ✔️ The file should have no headers and only contain compound names separated by commas.
# ✔️ If you don’t have a file, you can enter plant names manually.
# ❌ Only CSV files are accepted!
#
# 📌 Do you want to upload a CSV file? (yes/no): no
# 🌿 Enter plant/herb names (comma-separated): Aloe vera,Phyllanthus emblica,Murraya koenigii,Cinnamomum camphora,Cocos nucifera,Eclipta prostrata,Hibiscus rosa-sinensis,Lawsonia inermis,Azadirachta indica,Trigonella foenum-graecum,Salvia officinalis,Achyranthes aspera,Allium cepa,Vitis vinifera,Nardostachys jatamansi,Rosmarinus officinalis,Thymus vulgaris,Ocimum tenuiflorum,Allium sativum,Serenoa repens,Panax ginseng,Urtica dioica,Ricinus communis,Simmondsia chinensis,Arnica montana,Capsicum annuum,Nigella sativa,Acacia concinna,Moringa oleifera,Terminalia bellirica,Withania somnifera,Polygonum multiflorum,Angelica sinensis,Lycium barbarum,Ganoderma lucidum,Schisandra chinensis,Carthamus tinctorius,Cinnamomum verum,Angelica archangelica,Bacopa monnieri,Brassica juncea,Arctium lappa,Catharanthus roseus,Capsicum frutescens,Curcuma longa,Cymbopogon citratus,Cyperus rotundus,Equisetum arvense,Linum usitatissimum,Zingiber officinale,Glycyrrhiza glabra,Lavandula angustifolia,Citrus limon,Melaleuca alternifolia,Mentha piperita,Piper nigrum,Cucurbita pepo,Oryza sativa,Santalum album,Sapindus mukorossi,Scutellaria baicalensis,Sesamum indicum,Syzygium aromaticum,Thuja occidentalis,Ginkgo biloba,Camellia sinensis,Fucus vesiculosus,Polygonum cuspidatum,Foeniculum vulgare,Astragalus membranaceus,Apium graveolens,Celosia argentea,Angelica dahurica,Rheum palmatum,Paeonia lactiflora,Perilla frutescens,Prunus persica,Prunus mume,Eclipta alba,Murraya koenigii,Nigella sativa,Citrus limon,Cocos nucifera,Hibiscus rosa-sinensis,Aloe barbadensis,Cannabis sativa,Rubia cordifolia,Emblica officinalis,Celastrus paniculatus,Ficus benghalensis,Trigonella foenum-graecum,Lawsonia inermis,Acacia concinna,Bacopa monnieri,Ricinus communis,Rosa moschata,Azadirachta indica,Centella asiatica,Geranium wallichianum,Parmelia perlata,Sapindus trifoliatus,Nardostachys jatamansi,Pterocarpus santalinus,Cedrus deodara,Melaleuca leucadendron
#
# 🌱 Searching for 105 plants...
#
# 🔍 Searching compounds for aloe vera in the 🥥 COCONUT Database...
# ✅ Found 4 compounds: ['4-Chloro-3,5-Dimethylphenol', 'Isopropyl Alcohol', 'Benzethonium Chloride', 'Triclosan']
# 🔄 Processing 4-Chloro-3,5-Dimethylphenol from aloe vera...
# 🔄 Processing Isopropyl Alcohol from aloe vera...
# 🔄 Processing Benzethonium Chloride from aloe vera...
# 🔄 Processing Triclosan from aloe vera...
#
# 🔍 Searching compounds for phyllanthus emblica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for phyllanthus emblica as no valid compounds were found.
#
# 🔍 Searching compounds for murraya koenigii in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for murraya koenigii as no valid compounds were found.
#
# 🔍 Searching compounds for cinnamomum camphora in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for cinnamomum camphora as no valid compounds were found.
#
# 🔍 Searching compounds for cocos nucifera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for cocos nucifera as no valid compounds were found.
#
# 🔍 Searching compounds for eclipta prostrata in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for eclipta prostrata as no valid compounds were found.
#
# 🔍 Searching compounds for hibiscus rosa-sinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for hibiscus rosa-sinensis as no valid compounds were found.
#
# 🔍 Searching compounds for lawsonia inermis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for lawsonia inermis as no valid compounds were found.
#
# 🔍 Searching compounds for azadirachta indica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Nimbolide']
# 🔄 Processing Nimbolide from azadirachta indica...
#
# 🔍 Searching compounds for trigonella foenum-graecum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for trigonella foenum-graecum as no valid compounds were found.
#
# 🔍 Searching compounds for salvia officinalis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Epiisorosmanol']
# 🔄 Processing Epiisorosmanol from salvia officinalis...
#
# 🔍 Searching compounds for achyranthes aspera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for achyranthes aspera as no valid compounds were found.
#
# 🔍 Searching compounds for allium cepa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for allium cepa as no valid compounds were found.
#
# 🔍 Searching compounds for vitis vinifera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['ETHYL HEPTANOATE']
# 🔄 Processing ETHYL HEPTANOATE from vitis vinifera...
#
# 🔍 Searching compounds for nardostachys jatamansi in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for nardostachys jatamansi as no valid compounds were found.
#
# 🔍 Searching compounds for rosmarinus officinalis in the 🥥 COCONUT Database...
# ✅ Found 3 compounds: ['7-O-Methylrosmanol', 'Carnosic Acid', '(4aR)-5,6-Dihydroxy-1,1-Dimethyl-7-Propan-2-Yl-2,3,4,9,10,10a-Hexahydrophenanthrene-4a-Carboxylic Acid']
# 🔄 Processing 7-O-Methylrosmanol from rosmarinus officinalis...
# 🔄 Processing Carnosic Acid from rosmarinus officinalis...
# 🔄 Processing (4aR)-5,6-Dihydroxy-1,1-Dimethyl-7-Propan-2-Yl-2,3,4,9,10,10a-Hexahydrophenanthrene-4a-Carboxylic Acid from rosmarinus officinalis...
#
# 🔍 Searching compounds for thymus vulgaris in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for thymus vulgaris as no valid compounds were found.
#
# 🔍 Searching compounds for ocimum tenuiflorum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for ocimum tenuiflorum as no valid compounds were found.
#
# 🔍 Searching compounds for allium sativum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for allium sativum as no valid compounds were found.
#
# 🔍 Searching compounds for serenoa repens in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for serenoa repens as no valid compounds were found.
#
# 🔍 Searching compounds for panax ginseng in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Panax Ginseng Tetrapeptide']
# 🔄 Processing Panax Ginseng Tetrapeptide from panax ginseng...
#
# 🔍 Searching compounds for urtica dioica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for urtica dioica as no valid compounds were found.
#
# 🔍 Searching compounds for ricinus communis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for ricinus communis as no valid compounds were found.
#
# 🔍 Searching compounds for simmondsia chinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for simmondsia chinensis as no valid compounds were found.
#
# 🔍 Searching compounds for arnica montana in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for arnica montana as no valid compounds were found.
#
# 🔍 Searching compounds for capsicum annuum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Acetal']
# 🔄 Processing Acetal from capsicum annuum...
#
# 🔍 Searching compounds for nigella sativa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for nigella sativa as no valid compounds were found.
#
# 🔍 Searching compounds for acacia concinna in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for acacia concinna as no valid compounds were found.
#
# 🔍 Searching compounds for moringa oleifera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for moringa oleifera as no valid compounds were found.
#
# 🔍 Searching compounds for terminalia bellirica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for terminalia bellirica as no valid compounds were found.
#
# 🔍 Searching compounds for withania somnifera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Withanolide D']
# 🔄 Processing Withanolide D from withania somnifera...
#
# 🔍 Searching compounds for polygonum multiflorum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for polygonum multiflorum as no valid compounds were found.
#
# 🔍 Searching compounds for angelica sinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for angelica sinensis as no valid compounds were found.
#
# 🔍 Searching compounds for lycium barbarum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for lycium barbarum as no valid compounds were found.
#
# 🔍 Searching compounds for ganoderma lucidum in the 🥥 COCONUT Database...
# ✅ Found 3 compounds: ['ERGOSTEROL', 'Ganoderic Acid A', 'Ganoderic Acid B']
# 🔄 Processing ERGOSTEROL from ganoderma lucidum...
# 🔄 Processing Ganoderic Acid A from ganoderma lucidum...
# 🔄 Processing Ganoderic Acid B from ganoderma lucidum...
#
# 🔍 Searching compounds for schisandra chinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Schisandrin']
# 🔄 Processing Schisandrin from schisandra chinensis...
#
# 🔍 Searching compounds for carthamus tinctorius in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for carthamus tinctorius as no valid compounds were found.
#
# 🔍 Searching compounds for cinnamomum verum in the 🥥 COCONUT Database...
# ✅ Found 4 compounds: ['Eugenol', 'Cinnamtannin B2', 'Cinnamtannin B1', 'Coumarin']
# 🔄 Processing Eugenol from cinnamomum verum...
# 🔄 Processing Cinnamtannin B2 from cinnamomum verum...
# 🔄 Processing Cinnamtannin B1 from cinnamomum verum...
# 🔄 Processing Coumarin from cinnamomum verum...
#
# 🔍 Searching compounds for angelica archangelica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Isopimpinellin']
# 🔄 Processing Isopimpinellin from angelica archangelica...
#
# 🔍 Searching compounds for bacopa monnieri in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for bacopa monnieri as no valid compounds were found.
#
# 🔍 Searching compounds for brassica juncea in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for brassica juncea as no valid compounds were found.
#
# 🔍 Searching compounds for arctium lappa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for arctium lappa as no valid compounds were found.
#
# 🔍 Searching compounds for catharanthus roseus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for catharanthus roseus as no valid compounds were found.
#
# 🔍 Searching compounds for capsicum frutescens in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for capsicum frutescens as no valid compounds were found.
#
# 🔍 Searching compounds for curcuma longa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for curcuma longa as no valid compounds were found.
#
# 🔍 Searching compounds for cymbopogon citratus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for cymbopogon citratus as no valid compounds were found.
#
# 🔍 Searching compounds for cyperus rotundus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for cyperus rotundus as no valid compounds were found.
#
# 🔍 Searching compounds for equisetum arvense in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for equisetum arvense as no valid compounds were found.
#
# 🔍 Searching compounds for linum usitatissimum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for linum usitatissimum as no valid compounds were found.
#
# 🔍 Searching compounds for zingiber officinale in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for zingiber officinale as no valid compounds were found.
#
# 🔍 Searching compounds for glycyrrhiza glabra in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for glycyrrhiza glabra as no valid compounds were found.
#
# 🔍 Searching compounds for lavandula angustifolia in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for lavandula angustifolia as no valid compounds were found.
#
# 🔍 Searching compounds for citrus limon in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for citrus limon as no valid compounds were found.
#
# 🔍 Searching compounds for melaleuca alternifolia in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for melaleuca alternifolia as no valid compounds were found.
#
# 🔍 Searching compounds for mentha piperita in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for mentha piperita as no valid compounds were found.
#
# 🔍 Searching compounds for piper nigrum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for piper nigrum as no valid compounds were found.
#
# 🔍 Searching compounds for cucurbita pepo in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for cucurbita pepo as no valid compounds were found.
#
# 🔍 Searching compounds for oryza sativa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for oryza sativa as no valid compounds were found.
#
# 🔍 Searching compounds for santalum album in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['5-[(1S,3R)-2,3-Dimethyl-3-Tricyclo[2.2.1.02,6]Heptanyl]-2-Methylpent-2-En-1-Ol;2-Methyl-5-[(1S,2R,4R)-2-Methyl-3-Methylidene-2-Bicyclo[2.2.1]Heptanyl]Pent-2-En-1-Ol']
# 🔄 Processing 5-[(1S,3R)-2,3-Dimethyl-3-Tricyclo[2.2.1.02,6]Heptanyl]-2-Methylpent-2-En-1-Ol;2-Methyl-5-[(1S,2R,4R)-2-Methyl-3-Methylidene-2-Bicyclo[2.2.1]Heptanyl]Pent-2-En-1-Ol from santalum album...
#
# 🔍 Searching compounds for sapindus mukorossi in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for sapindus mukorossi as no valid compounds were found.
#
# 🔍 Searching compounds for scutellaria baicalensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for scutellaria baicalensis as no valid compounds were found.
#
# 🔍 Searching compounds for sesamum indicum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for sesamum indicum as no valid compounds were found.
#
# 🔍 Searching compounds for syzygium aromaticum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for syzygium aromaticum as no valid compounds were found.
#
# 🔍 Searching compounds for thuja occidentalis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for thuja occidentalis as no valid compounds were found.
#
# 🔍 Searching compounds for ginkgo biloba in the 🥥 COCONUT Database...
# ✅ Found 4 compounds: ['Ginkgolide B', 'Ginkgolide A', 'Bilobalide', 'Ginkgolide A']
# 🔄 Processing Ginkgolide B from ginkgo biloba...
# 🔄 Processing Ginkgolide A from ginkgo biloba...
# 🔄 Processing Bilobalide from ginkgo biloba...
# 🔄 Processing Ginkgolide A from ginkgo biloba...
#
# 🔍 Searching compounds for camellia sinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for camellia sinensis as no valid compounds were found.
#
# 🔍 Searching compounds for fucus vesiculosus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['(2S,3S,4S,5S,6R)-4,5-Dihydroxy-2,6-Dimethyltetrahydro-2H-Pyran-3-Yl Hydrogen Sulfate']
# 🔄 Processing (2S,3S,4S,5S,6R)-4,5-Dihydroxy-2,6-Dimethyltetrahydro-2H-Pyran-3-Yl Hydrogen Sulfate from fucus vesiculosus...
#
# 🔍 Searching compounds for polygonum cuspidatum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for polygonum cuspidatum as no valid compounds were found.
#
# 🔍 Searching compounds for foeniculum vulgare in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for foeniculum vulgare as no valid compounds were found.
#
# 🔍 Searching compounds for astragalus membranaceus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for astragalus membranaceus as no valid compounds were found.
#
# 🔍 Searching compounds for apium graveolens in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for apium graveolens as no valid compounds were found.
#
# 🔍 Searching compounds for celosia argentea in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for celosia argentea as no valid compounds were found.
#
# 🔍 Searching compounds for angelica dahurica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for angelica dahurica as no valid compounds were found.
#
# 🔍 Searching compounds for rheum palmatum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for rheum palmatum as no valid compounds were found.
#
# 🔍 Searching compounds for paeonia lactiflora in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for paeonia lactiflora as no valid compounds were found.
#
# 🔍 Searching compounds for perilla frutescens in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for perilla frutescens as no valid compounds were found.
#
# 🔍 Searching compounds for prunus persica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for prunus persica as no valid compounds were found.
#
# 🔍 Searching compounds for prunus mume in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for prunus mume as no valid compounds were found.
#
# 🔍 Searching compounds for eclipta alba in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for eclipta alba as no valid compounds were found.
#
# 🔍 Searching compounds for murraya koenigii in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for murraya koenigii as no valid compounds were found.
#
# 🔍 Searching compounds for nigella sativa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for nigella sativa as no valid compounds were found.
#
# 🔍 Searching compounds for citrus limon in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for citrus limon as no valid compounds were found.
#
# 🔍 Searching compounds for cocos nucifera in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for cocos nucifera as no valid compounds were found.
#
# 🔍 Searching compounds for hibiscus rosa-sinensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for hibiscus rosa-sinensis as no valid compounds were found.
#
# 🔍 Searching compounds for aloe barbadensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Aloin']
# 🔄 Processing Aloin from aloe barbadensis...
#
# 🔍 Searching compounds for cannabis sativa in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for cannabis sativa as no valid compounds were found.
#
# 🔍 Searching compounds for rubia cordifolia in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for rubia cordifolia as no valid compounds were found.
#
# 🔍 Searching compounds for emblica officinalis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for emblica officinalis as no valid compounds were found.
#
# 🔍 Searching compounds for celastrus paniculatus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for celastrus paniculatus as no valid compounds were found.
#
# 🔍 Searching compounds for ficus benghalensis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for ficus benghalensis as no valid compounds were found.
#
# 🔍 Searching compounds for trigonella foenum-graecum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for trigonella foenum-graecum as no valid compounds were found.
#
# 🔍 Searching compounds for lawsonia inermis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for lawsonia inermis as no valid compounds were found.
#
# 🔍 Searching compounds for acacia concinna in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for acacia concinna as no valid compounds were found.
#
# 🔍 Searching compounds for bacopa monnieri in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for bacopa monnieri as no valid compounds were found.
#
# 🔍 Searching compounds for ricinus communis in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for ricinus communis as no valid compounds were found.
#
# 🔍 Searching compounds for rosa moschata in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for rosa moschata as no valid compounds were found.
#
# 🔍 Searching compounds for azadirachta indica in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['Nimbolide']
# 🔄 Processing Nimbolide from azadirachta indica...
#
# 🔍 Searching compounds for centella asiatica in the 🥥 COCONUT Database...
# ✅ Found 6 compounds: ['Madecassic Acid', 'Asiaticoside', 'Asiatic Acid', 'Madecassoside', 'Terminolic Acid', 'ASIATICOSIDE B']
# 🔄 Processing Madecassic Acid from centella asiatica...
# 🔄 Processing Asiaticoside from centella asiatica...
# 🔄 Processing Asiatic Acid from centella asiatica...
# 🔄 Processing Madecassoside from centella asiatica...
# 🔄 Processing Terminolic Acid from centella asiatica...
# 🔄 Processing ASIATICOSIDE B from centella asiatica...
#
# 🔍 Searching compounds for geranium wallichianum in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for geranium wallichianum as no valid compounds were found.
#
# 🔍 Searching compounds for parmelia perlata in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for parmelia perlata as no valid compounds were found.
#
# 🔍 Searching compounds for sapindus trifoliatus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for sapindus trifoliatus as no valid compounds were found.
#
# 🔍 Searching compounds for nardostachys jatamansi in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for nardostachys jatamansi as no valid compounds were found.
#
# 🔍 Searching compounds for pterocarpus santalinus in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for pterocarpus santalinus as no valid compounds were found.
#
# 🔍 Searching compounds for cedrus deodara in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for cedrus deodara as no valid compounds were found.
#
# 🔍 Searching compounds for melaleuca leucadendron in the 🥥 COCONUT Database...
# ✅ Found 1 compounds: ['No results']
# ⚠️ Skipping PubChem search for melaleuca leucadendron as no valid compounds were found.
#
# ✅ Data successfully saved to `natural_products.csv`!

# %%
import pandas as pd

# File paths
file_paths = [
    "/content/natural_products.csv",
    "/content/natural_products(1).csv",
    "/content/natural_products(2).csv",
    "/content/natural_products(3).csv",
]

# Load and concatenate all CSV files
dfs = [pd.read_csv(file) for file in file_paths]
combined_df = pd.concat(dfs, ignore_index=True)

# Drop duplicates based on "Compound" column (assuming it defines uniqueness)
unique_df = combined_df.drop_duplicates(subset=["Compound"])

# Save the unique results to a new file
unique_file_path = "/content/unique_compounds.csv"
unique_df.to_csv(unique_file_path, index=False)

# Display number of unique records
len(unique_df), unique_file_path
# Out:
# (282, '/content/unique_compounds.csv')

# %%
# Select only the "Plant", "Compound", and "CanonicalSMILES" columns
selected_columns = unique_df[["Compound", "CanonicalSMILES"]]

# Display the first few rows
selected_columns.head()
# Out:
#                       Compound  \
# 0  4-Chloro-3,5-Dimethylphenol
# 1            Isopropyl Alcohol
# 2        Benzethonium Chloride
# 3                    Triclosan
# 4                    Nimbolide
#
#                                      CanonicalSMILES
# 0                               CC1=CC(=CC(=C1Cl)C)O
# 1                                             CC(C)O
# 2  CC(C)(C)CC(C)(C)C1=CC=C(C=C1)OCCOCC[N+](C)(C)C...
# 3             C1=CC(=C(C=C1Cl)O)OC2=C(C=C(C=C2)Cl)Cl
# 4  CC1=C2C(CC1C3=COC=C3)OC4C2(C(C5(C6C4OC(=O)C6(C...

# %%
# Load the newly uploaded file
file_path = "/content/Alopecia Natural Product Compounds updated - uniqueresult.csv"
df = pd.read_csv(file_path)

# Remove duplicate rows based on all columns to keep only unique records
unique_df = df.drop_duplicates()

# Save the unique dataset
unique_file_path = "/content/unique_results.csv"
unique_df.to_csv(unique_file_path, index=False)

# Display the number of unique records and provide the download link
len(unique_df), unique_file_path
# Out:
# (380, '/content/unique_results.csv')

# %%
# Drop all rows that contain any blank (NaN) values
cleaned_df = unique_df.dropna()

# Save the cleaned dataset without blanks
cleaned_file_path = "/content/unique_results.csv"
cleaned_df.to_csv(cleaned_file_path, index=False)

# Display the number of records after removing blanks
len(cleaned_df), cleaned_file_path
# Out:
# (328, '/content/unique_results.csv')

# %%
import pandas as pd

# Load the CSV file from Google Colab (Uncomment the below lines if using Colab)
# from google.colab import files
# uploaded = files.upload()
# file_name = list(uploaded.keys())[0]  # Get the uploaded file name

file_path = "/content/alldataa.csv"  # Update this path for Google Colab

# Read the CSV file with error handling
df = pd.read_csv(file_path, on_bad_lines='skip')

# Check column names to ensure correct selection
print("Columns:", df.columns)

# Ensure column names are correct (Adjust if needed)
ligand_col = "ligand"  # Change if the ligand column has a different name
gscore_col = "GScore"  # Change if the GScore column has a different name

# Convert GScore column to numeric in case of formatting issues
df[gscore_col] = pd.to_numeric(df[gscore_col], errors='coerce')

# Filter ligands where GScore < -11 (since scores are negative)
filtered_df = df[df[gscore_col] < -11]

# Keep only unique ligands
unique_ligands = filtered_df[[ligand_col, gscore_col]].drop_duplicates()

# Display the results
print(unique_ligands)

# Save filtered results to a new CSV file
unique_ligands.to_csv("filtered_ligands.csv", index=False)
# Out:
# Columns: Index(['ligand', 'GScore', 'DockScore', 'LipophilicEvdW', 'PhobEn', 'PhobEnHB',
#        'PhobEnPairHB', 'HBond', 'Electro', 'Sitemap', 'PiCat', 'ClBr', 'LowMW',
#        'Penalties', 'HBPenal', 'ExposPenal', 'RotPenal', 'EpikStatePenalty',
#        'Zpotr', 'Similarity', 'Activity'],
#       dtype='object')
#                                 ligand  GScore
# 0                         Angoroside C  -16.11
# 1                   Gingerglycolipid A  -16.03
# 2                           Perillanin  -16.01
# 3                       Angoroside C-2  -15.97
# 4     Secoisolariciresinol Diglucoside  -15.76
# ...                                ...     ...
# 999                     Isobiflorin-30  -11.07
# 1008                    Isobiflorin-31  -11.05
# 1043                    Thymectacin-25  -11.06
# 1046                   Cinnamtannin B2  -11.19
# 1060                     Perillanin-32  -11.06
#
# [539 rows x 2 columns]
